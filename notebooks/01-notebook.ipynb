# %%
from image_metadata_lab.exif_reader import read_exif_summary

# %% [markdown]
# ### Read EXIF metadata from an image

# %%
image_path = "../data/input/IMG20260203155910.jpg"

# %%
summary = read_exif_summary(image_path)
summary
# Out:
# ExifSummary(date_time_original=datetime.datetime(2026, 2, 3, 15, 59, 10), latitude=-7.024003027777778, longitude=112.74541472222222, raw={'ImageWidth': 2016, 'ImageLength': 4480, 'ImageDescription': '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', 'Make': 'realme\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', 'Model': 'realme 7\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', 'Orientation': 0, 'YCbCrPositioning': 2, 'XResolution': 72.0, 'YResolution': 72.0, '544': 0, '545': 0, '546': 0, '547': 0, '548': 0, '549': '\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', 'GPSInfo': 1404, 'ResolutionUnit': 2, 'Software': 'MediaTek Camera Application\x00\x00\x00\x00', 'DateTime': '2026:02:03 15:59:10', 'ExifOffset': 450, 'GPSInfoParsed': {'GP
# ...

# %% [markdown]
# **Print datetime, latitude and longitude**

# %%
summary.date_time_original
# Out:
# datetime.datetime(2026, 2, 3, 15, 59, 10)

# %%
summary.latitude
# Out:
# -7.024003027777778

# %%
summary.longitude
# Out:
# 112.74541472222222
